# %% [markdown]
# ###### EEG - Flow
#
# ## 7. Epochs Evokeds
#
#
# Last edit: 08.05.2023 00:25
# @anguyen

# %%
from eeg_flow.tasks import behav_prep_epoching
# Out:
# 2023-11-17 17:58:24,172 - numexpr.utils - INFO - Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2023-11-17 17:58:24,175 - numexpr.utils - INFO - NumExpr defaulting to 8 threads.

# %% [markdown]
# The parameters of the file to process are defined below. Locks are created to prevent someone else from running the same task and from writing the same derivatives.

# %%
"""
PARTICIPANT: str (for example "P03", "P28")
GROUP:       str ["G1", "G2", "G3", "G4", "G5", "G6", "G7", "G8"]
TASK:        str, ["oddball", "UT"]
RUN:         int [1, 2]
ICA_NB:      int [1, 2]
"""

PARTICIPANT = "P01"
GROUP       = "G1"
TASK        = "oddball"
RUN         = 1

# %%
behav_prep_epoching(PARTICIPANT, GROUP, TASK, RUN)
# Out:
# Opening raw data file L:\EEG_Flow_data\Study_EEG_Flow_Active\derivatives\sub-P01-G1\sub-P01-G1_task-oddball_run-1\sub-P01-G1_task-oddball_run-1_step7_preprocessed_raw.fif...
#     Range : 6592 ... 392031 =      6.438 ...   382.843 secs
# Ready.
# Reading 0 ... 385439  =      0.000 ...   376.405 secs...
# 397 events found
# Event IDs: [ 1  2  3 64]
#
# Correct responses: 360
# Incorrect responses: 0
#
# Hits, Misses, Correct Rejections, False Alarms
# 36 0 324 0
#
# Adding metadata with 7 columns
# 360 matching events found
# Setting baseline interval to [-0.2001953125, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 360 events and 1025 original time points ...
# 1 bad epochs dropped
# Estimating rejection dictionary for eeg
#
# Peak-to-peak rejection threshold computed: %s {'eeg': 7.588486914755777e-05}
# Elapsed 00:11
#
#     Rejecting  epoch based on EEG : ['F4', 'T7', 'POz', 'F1', 'F2', 'P1', 'P2', 'CPz']
#     Rejecting  epoch based on EEG : ['FC1', 'FC2', 'C3', 'Cz', 'CP1', 'CP2', 'CP6', 'P4', 'F1', 'F2', 'FC3', 'FCz', 'C1', 'C2', 'CP3', 'CP4', 'P1', 'P2', 'P6', 'CPz']
#     Rejecting  epoch based on EEG : ['F2', 'CP3']
#     Rejecting  epoch based on EEG : ['P3']
#     Rejecting  epoch based on EEG : ['P2']
#     Rejecting  epoch based on EEG : ['F3', 'C3', 'Cz', 'CP5', 'CP1', 'CP2', 'P7', 'P3', 'P4', 'C5', 'C1', 'C2', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'CPz']
#     Rejecting  epoch based on EEG : ['P3']
#     Rejecting  epoch based on EEG : ['FC1', 'FC2', 'C3', 'Cz', 'C4', 'CP1', 'CP2', 'CP6', 'Pz', 'P4', 'FCz', 'C1', 'C2', 'C6', 'CP3', 'CP4', 'P1', 'P2', 'P6', 'CPz']
#     Rejecting  epoch based on EEG : ['CP5', 'CP1', 'CP2', 'P3', 'Pz', 'P4', 'POz', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO5', 'PO3', 'PO4', 'CPz']
#     Rejecting  epoch based on EEG : ['CP2', 'P3', 'Pz', 'P4', 'CP4', 'P1', 'P2']
#     Rejecting  epoch based on EEG : ['CP2', 'P4', 'P2']
#     Rejecting  epoch based on EEG : ['CP1', 'P3', 'Pz', 'CP3', 'P1', 'P2', 'CPz']
#     Rejecting  epoch based on EEG : ['P2']
#     Rejecting  epoch based on EEG : ['FCz']
#     Rejecting  epoch based on EEG : ['CP1', 'CP4', 'P2', 'CPz']
#     Rejecting  epoch based on EEG : ['PO8']
#     Rejecting  epoch based on EEG : ['Cz', 'C4', 'CP2', 'Pz', 'P4', 'C2', 'CP4', 'P2', 'CPz']
#     Rejecting  epoch based on EEG : ['P2']
#     Rejecting  epoch based on EEG : ['CP1', 'CP2', 'P3', 'Pz', 'P4', 'F2', 'C1', 'C2', 'C6', 'CP3', 'P1', 'CPz']
#     Rejecting  epoch based on EEG : ['F1']
#     Rejecting  epoch based on EEG : ['P4']
#     Rejecting  epoch based on EEG : ['Pz', 'F1', 'FCz', 'P2']
#     Rejecting  epoch based on EEG : ['FC1', 'FC2', 'Cz', 'C4', 'CP1', 'CP2', 'Pz', 'P4', 'POz', 'F2', 'FCz', 'C1', 'C2', 'CP4', 'P1', 'P2', 'P6', 'PO4', 'PO6', 'CPz']
#     Rejecting  epoch based on EEG : ['P4']
#     Rejecting  epoch based on EEG : ['P4', 'CP4', 'P2', 'P6']
#     Rejecting  epoch based on EEG : ['AF4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['F7', 'F3', 'Fz', 'F4', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'CP5', 'CP1', 'P7', 'P3', 'Pz', 'P4', 'AF7', 'AF3', 'AF4', 'F5', 'F2', 'FC3', 'FCz', 'FC4', 'C5', 'C1', 'C6', 'CP3', 'CP4', 'P5', 'P1', 'PO5', 'PO3', 'FT7', 'FT8', 'TP7', 'PO7', 'CPz']
#     Rejecting  epoch based on EEG : ['C4', 'CP1', 'CP2', 'Pz', 'P4', 'C2', 'CP3', 'CP4', 'P1', 'CPz']
#     Rejecting  epoch based on EEG : ['P4', 'P5', 'P2', 'P6', 'PO4', 'PO6', 'PO8']
#     Rejecting  epoch based on EEG : ['CP2', 'P3', 'Pz', 'P4', 'CP4', 'P1', 'P2', 'P6', 'PO4', 'CPz']
#     Rejecting  epoch based on EEG : ['Pz', 'P1', 'P2', 'CPz']
#     Rejecting  epoch based on EEG : ['CP1', 'CP2', 'P3', 'Pz', 'P4', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO8', 'CPz']
#     Rejecting  epoch based on EEG : ['F2']
#     Rejecting  epoch based on EEG : ['CP2', 'CP4', 'CPz']
#     Rejecting  epoch based on EEG : ['CPz']
#     Rejecting  epoch based on EEG : ['Fz', 'F4', 'FC5', 'FC1', 'FC2', 'C3', 'Cz', 'C4', 'CP5', 'CP1', 'CP2', 'CP6', 'Pz', 'P4', 'F1', 'F2', 'FC3', 'C5', 'C1', 'C2', 'CP4', 'P2', 'P6', 'PO4', 'CPz']
#     Rejecting  epoch based on EEG : ['P2']
#     Rejecting  epoch based on EEG : ['FC2', 'Cz', 'CP1', 'CP2', 'CP6', 'P3', 'Pz', 'P4', 'F2', 'FCz', 'C1', 'C2', 'CP4', 'P1', 'P2', 'P6', 'PO4', 'PO6', 'CPz']
#     Rejecting  epoch based on EEG : ['C4', 'CP1', 'CP2', 'P3', 'Pz', 'P4', 'POz', 'CP3', 'CP4', 'P1', 'P2', 'P6', 'PO4', 'CPz']
#     Rejecting  epoch based on EEG : ['CP2', 'Pz', 'P2']
#     Rejecting  epoch based on EEG : ['CP4', 'P6']
#     Rejecting  epoch based on EEG : ['Fp1', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'AF4', 'F1', 'F2', 'FC3', 'FCz', 'FC4', 'C5', 'C1', 'C2', 'C6', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO5', 'PO3', 'PO4', 'PO6', 'TP8', 'PO8', 'CPz']
#     Rejecting  epoch based on EEG : ['F3', 'C3', 'CP5', 'CP1', 'AF4', 'F1', 'C5', 'CP3', 'P5']
#     Rejecting  epoch based on EEG : ['C3', 'Cz', 'C4', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O2', 'F1', 'C5', 'C1', 'C2', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO5', 'PO3', 'PO4', 'PO6', 'PO8', 'CPz']
#     Rejecting  epoch based on EEG : ['CP3', 'P1']
#     Rejecting  epoch based on EEG : ['Cz', 'CP2', 'Pz', 'P4', 'POz', 'CP4', 'P2', 'P6', 'PO4', 'PO6', 'CPz']
#     Rejecting  epoch based on EEG : ['CP1', 'CP2', 'Pz', 'P4', 'POz', 'C1', 'CP4', 'P1', 'P2', 'P6', 'PO4', 'CPz']
#     Rejecting  epoch based on EEG : ['Cz', 'CP2', 'C2', 'CP4', 'CPz']
#     Rejecting  epoch based on EEG : ['CP5', 'CP1', 'P3', 'CP3', 'P5', 'TP7']
#     Rejecting  epoch based on EEG : ['CP5', 'P5']
#     Rejecting  epoch based on EEG : ['FC2', 'FC6', 'Cz', 'C4', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'C1', 'C2', 'C6', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO5', 'PO3', 'PO4', 'PO7', 'CPz']
#     Rejecting  epoch based on EEG : ['FC2', 'Cz', 'F1', 'F2', 'FCz', 'C1']
#     Rejecting  epoch based on EEG : ['Fz', 'F1']
#     Rejecting  epoch based on EEG : ['CP2', 'Pz', 'P4', 'P2', 'CPz']
#     Rejecting  epoch based on EEG : ['F7', 'Fz', 'F4', 'FC5', 'FC1', 'FC2', 'T7', 'C3', 'Cz', 'C4', 'CP5', 'CP1', 'CP2', 'CP6', 'P3', 'Pz', 'P4', 'POz', 'F2', 'FC3', 'FCz', 'FC4', 'C5', 'C1', 'C2', 'C6', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO3', 'PO4', 'PO6', 'PO8', 'CPz']
#     Rejecting  epoch based on EEG : ['CP2', 'Pz', 'P4', 'P2', 'CPz']
#     Rejecting  epoch based on EEG : ['CP4']
#     Rejecting  epoch based on EEG : ['P4', 'P2']
#     Rejecting  epoch based on EEG : ['FC5', 'FC1', 'C4', 'CP1', 'CP2', 'CP6', 'P3', 'Pz', 'P4', 'F5', 'F1', 'C2', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO3', 'PO4', 'PO6', 'CPz']
#     Rejecting  epoch based on EEG : ['CP2', 'P4', 'CP4', 'P2', 'P6']
#     Rejecting  epoch based on EEG : ['CPz']
#     Rejecting  epoch based on EEG : ['T7', 'C3', 'CP5', 'P7', 'P3', 'C5', 'CP3', 'P5', 'P1', 'P6', 'PO6', 'TP7', 'PO8']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'CP5', 'CP1', 'P7', 'P3', 'Pz', 'P4', 'C5', 'C1', 'CP3', 'P5', 'P1', 'PO5', 'PO3', 'TP7']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'F7', 'F3', 'Fz', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'CP5', 'CP1', 'CP2', 'CP6', 'P3', 'Pz', 'P4', 'P8', 'POz', 'AF7', 'AF3', 'AF4', 'F5', 'F1', 'F2', 'FC3', 'FCz', 'FC4', 'C5', 'C1', 'C2', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO5', 'PO3', 'PO4', 'PO6', 'FT7', 'TP7', 'PO8', 'CPz']
#     Rejecting  epoch based on EEG : ['PO8']
#     Rejecting  epoch based on EEG : ['P7', 'P3', 'Pz', 'P8', 'POz', 'O2', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO5', 'PO3', 'PO4', 'PO6', 'PO8', 'CPz']
#     Rejecting  epoch based on EEG : ['P4', 'P2', 'P6', 'PO4', 'PO6']
#     Rejecting  epoch based on EEG : ['P4']
#     Rejecting  epoch based on EEG : ['CP1', 'CP2', 'P4', 'C2', 'CP4', 'P2', 'CPz']
#     Rejecting  epoch based on EEG : ['PO8']
# 71 bad epochs dropped
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).

# %% [markdown]
# Output of step 9
# - Metadata (_a-metadata.csv)
# - Behav summary (_b-behav.txt)
# - Epochs (_c1-cleaned-epo.fif)
# - CSV count dropped event (_c2-drop-epochs.csv)
# - CSV count dropped by channels (_c3-dropped-channel-log.csv)
# - Standard evoked (_d1-standard_evoked-ave.fif)
# - Target evoked (_d2-target_evoked-ave.fif)
# - Novel evoked (_d3-novel_evoked-ave.fif)
